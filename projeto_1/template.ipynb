# %% [markdown]
# # Projeto #1 - Análise Exploratória de Dados
#
# Antes de começar, leia as [Instruções](https://github.com/thvmm/pos-ds-ia/tree/master/projeto_1#instru%C3%A7%C3%B5es) e os [Critérios de Avaliação](https://github.com/thvmm/pos-ds-ia/tree/master/projeto_1#crit%C3%A9rios-de-avalia%C3%A7%C3%A3o)

# %% [markdown]
# ### 1) Qual a base escolhida e qual seu interesse nela? **5%**

# %% [markdown]
# *Indique o link da base no Kaggle e explique em um parágrafo curto por que essa base é interessante para você.*

# %% [markdown]
# ### 2) Descrição básica do conjunto de dados escolhido pelo aluno (1 paragrafo). **5%**
# - Identificação da variável a serem trabalhadas
# - Classificação das váriaveis como: contínua ou discreta.

# %% [markdown]
# *Descrição da base e suas váriaveis*

# %% [markdown]
# ### 2) Faça uma avaliação descritiva da sua base. Quantas linhas ela possui? Quais os tipos de dados? Quantas e quais features possuem? **15%**
#
# Cada variável escolhida pelo aluno precisa passar por ao menos 1 pre-processamento. O pre-processamento pode ser (mas não está limitado a):
# - Checagem se os valores estão dentro de um limite permitido ou razóavel.
# - Tratamento de valores ausentes por eliminação ou substituição.
# - Conversão do tipo de dados.

# %%
# Implemente sua análise aqui. Use mais blocos se achar que ficará mais organizado.

# %% [markdown]
# ### 4) Nos blocos seguintes construa análises que vão justificar suas conclusões. **60%**

# %% [markdown]
# #### 4.1) Análise 1 -  Distribuição dos valores para cada uma das varíaveis **20%**
# - Exemplo para varíavel contínua: se o conjunto de dados possui a variável "idade". Quantos % possui a idade entre 0 e 30 anos? 31 a 59? 60+?
#
# - Exemplo para varíavel discreta: se o conjunto de dados possui a variável "gênero", quantos % do conjunto de dados é do sexo feminino, quantos % é masculino? Inclua outros gêneros se houver.

# %%
# Implemente sua análise aqui. Use mais blocos se achar que ficará mais organizado.

# %% [markdown]
# #### 4.2) Análise 2 **20%**

# %%
# Implemente sua análise aqui. Use mais blocos se achar que ficará mais organizado.

# %% [markdown]
# #### 4.3) Análise 3 **20%**

# %%
# Implemente sua análise aqui. Use mais blocos se achar que ficará mais organizado.

# %% [markdown]
# ### 5) Conclusões **15%**

# %% [markdown]
# *O que é possível concluir com os dados qeu você analisou? Se fosse fazer uma apresentação, o que levaria como os maiores destaques e por que?*
